# %%
import numpy
import cv2
from matplotlib import pyplot as plt

# %%
image1 = cv2.imread("blocky.png")
image2 = cv2.imread("snake-game.png")
image3 = cv2.imread("chatbot.png")

w,h,c = image3.shape
w = w//2
h = h//2

# %%
image1 = cv2.resize(image1, (h,w), interpolation=cv2.INTER_CUBIC)
image2 = cv2.resize(image2, (h,w), interpolation=cv2.INTER_CUBIC)
image3 = cv2.resize(image3, (h,w), interpolation=cv2.INTER_CUBIC)

# %%
print(image1.shape)
print(image2.shape)
print(image3.shape)
# Out:
# (268, 249, 3)
# (268, 249, 3)
# (268, 249, 3)

# %%
cv2.imwrite("snake-game.png", image2)
cv2.imwrite("blocky.png", image1)
cv2.imwrite("chatbot.png", image3)
# Out:
# True

# %%
plt.subplot(1,3,1)
plt.imshow(image1)
plt.subplot(1,3,2)
plt.imshow(image2)
plt.subplot(1,3,3)
plt.imshow(image3)
